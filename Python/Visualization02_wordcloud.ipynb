# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

from PIL import Image
#import nltk
from konlpy.corpus import kobill

# %%
#!pip install konlpy

# %%
from konlpy.tag import Twitter
from sklearn.feature_extraction.text import CountVectorizer
from PIL import Image
from wordcloud import WordCloud, STOPWORDS

# %%
from konlpy.tag import Okt;

# %%
tagger = Okt()

# %%
def get_word(sentence):
    nouns = tagger.nouns(sentence)
    return [nount for noun in nouns if len(noun) > 1]

# %%
test = open('./test1.txt', encoding='utf-8').read()

# %%
#!pip install nltk

# %%
#tokens_ko = tagger.nouns(novel)
#tokens_ko

# %%
import nltk

# %%
ko = nltk.Text(tokens_ko, name='keywert')

# %%
import matplotlib as mpl
mpl.rc('font', family='Hancom Gothic')
f_path = 'C://Windows/Fonts/malgun.ttf'

# %%
#data = ko.vocab().most_common(200)

#wordcloud = WordCloud(font_path=f_path, relative_scaling = 0.2, background_color='white',
#                    ).generate_from_frequencies(dict(data))

#plt.figure(figsize=(12, 9))
#plt.imshow(wordcloud)
#plt.axis('off')
#plt.show()

# %%
wordcloud.to_file('N.png')

# %%
img_mask = np.array(Image.open('./07. alice_mask.png'))
plt.figure(figsize=(8, 8))
plt.imshow(img_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#wc = WordCloud(background_color='white', max_words=2000, mask=img_mask)
#wc = wc.generate(test)
#wc.words_

# %%
#plt.figure(figsize=(12, 12))
#plt.imshow(wc, interpolation='bilinear')
#plt.axis('off')
#plt.show()

# %%
#plt.imshow(img_mask, cmap=plt.cm.gray, interpolation='bilinear')
#plt.axis('off')
#plt.show()

# %%
mask = np.array(Image.open('./그림1.png'))

# %%
text = open('./test1.txt', encoding='utf-8').read()

# %%
wc = WordCloud(font_path=f_path, background_color='white', 
               max_words=20000, 
               mask=mask, 
               max_font_size=300).generate_from_frequencies(dict(data))

# %%
#img_mask = np.array(Image.open('./그림2.png'))
#plt.figure(figsize=(8, 8))
#plt.imshow(img_mask, cmap=plt.cm.gray, interpolation='bilinear')
#plt.axis('off')
#plt.show()

# %%
wc = WordCloud(font_path=f_path,
               background_color='white', max_words=2000, mask=img_mask,
              max_font_size=300).generate_from_frequencies(dict(data))
#wc = wc.generate(test)
#wc.words_

# %%
#plt.figure(figsize=(12, 12))
#plt.imshow(wc, interpolation='bilinear')
#plt.axis('off')
#plt.show()

# %%
wc.to_file('N2.png')
